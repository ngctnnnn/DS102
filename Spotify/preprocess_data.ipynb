# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_artist = pd.read_csv('data_by_artist_o.csv')
df_artist
# Out:
#                                                   genres  \
# 0                                         ['show tunes']
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 28675                                                 []
# 28676  ['c-pop', 'classic cantopop', 'classic mandopo...
# 28677                                                 []
# 28678            ['chinese indie', 'chinese indie rock']
# 28679                             ['classic korean pop']
#
#                                                  artists  acousticness  \
# 0                       "Cats" 1981 Original London Cast      0.590111
# 1                              "Cats" 1983 Broadway Cast      0.862538
# ...

# %%
df_artist = df_artist.drop(columns = ['genres', 'artists'])

# %%
df_artist
# Out:
#        acousticness  danceability    duration_ms    energy  instrumentalness  \
# 0          0.590111      0.467222  250318.555556  0.394003          0.011400
# 1          0.862538      0.441731  287280.000000  0.406808          0.081158
# 2          0.856571      0.348286  328920.000000  0.286571          0.024593
# 3          0.884926      0.425074  262890.962963  0.245770          0.073587
# 4          0.510714      0.467143  270436.142857  0.488286          0.009400
# ...             ...           ...            ...       ...               ...
# 28675      0.512000      0.356000  198773.000000  0.306000          0.008970
# 28676      0.541000      0.578000  293840.000000  0.334000          0.000006
# 28677      0.785455      0.570818  174582.727273  0.148400          0.000083
# 28678      0.381000      0.353000  316160.000000  0.686000          0.000000
# 28679      0.568000      0.447000  237688.000000  0.215000          0.000001
#
# ...

# %%
df_genres = pd.read_csv('data_by_genres_o.csv')
df_genres
# Out:
#       mode                  genres  acousticness  danceability   duration_ms  \
# 0        1  21st century classical      0.979333      0.162883  1.602977e+05
# 1        1                   432hz      0.494780      0.299333  1.048887e+06
# 2        1                   8-bit      0.762000      0.712000  1.151770e+05
# 3        1                      []      0.651417      0.529093  2.328809e+05
# 4        1              a cappella      0.676557      0.538961  1.906285e+05
# ...    ...                     ...           ...           ...           ...
# 2968     1                    zolo      0.222625      0.547082  2.580991e+05
# 2969     0                 zouglou      0.161000      0.863000  2.063200e+05
# 2970     1                    zouk      0.263261      0.748889  3.060728e+05
# 2971     0            zurich indie      0.993000      0.705667  1.984173e+05
# 2972     1                  zydeco      0.421038      0.629409  1.716717e+05
#
# ...

# %%
df_genres = df_genres.drop(columns=['genres'])
df_genres
# Out:
#       mode  acousticness  danceability   duration_ms    energy  \
# 0        1      0.979333      0.162883  1.602977e+05  0.071317
# 1        1      0.494780      0.299333  1.048887e+06  0.450678
# 2        1      0.762000      0.712000  1.151770e+05  0.818000
# 3        1      0.651417      0.529093  2.328809e+05  0.419146
# 4        1      0.676557      0.538961  1.906285e+05  0.316434
# ...    ...           ...           ...           ...       ...
# 2968     1      0.222625      0.547082  2.580991e+05  0.610240
# 2969     0      0.161000      0.863000  2.063200e+05  0.909000
# 2970     1      0.263261      0.748889  3.060728e+05  0.622444
# 2971     0      0.993000      0.705667  1.984173e+05  0.172667
# 2972     1      0.421038      0.629409  1.716717e+05  0.609369
#
#       instrumentalness  liveness   loudness  speechiness       tempo  \
# 0             0.606834  0.361600 -31.514333     0.040567   75.336500
# ...

# %%
''' Change df_artist columns to fit df_genres '''
cols = df_genres.columns.tolist()
df_artist[cols]
# Out:
#        mode  acousticness  danceability    duration_ms    energy  \
# 0         1      0.590111      0.467222  250318.555556  0.394003
# 1         1      0.862538      0.441731  287280.000000  0.406808
# 2         1      0.856571      0.348286  328920.000000  0.286571
# 3         1      0.884926      0.425074  262890.962963  0.245770
# 4         1      0.510714      0.467143  270436.142857  0.488286
# ...     ...           ...           ...            ...       ...
# 28675     1      0.512000      0.356000  198773.000000  0.306000
# 28676     0      0.541000      0.578000  293840.000000  0.334000
# 28677     1      0.785455      0.570818  174582.727273  0.148400
# 28678     1      0.381000      0.353000  316160.000000  0.686000
# 28679     1      0.568000      0.447000  237688.000000  0.215000
#
#        instrumentalness  liveness   loudness  speechiness       tempo  \
# 0              0.011400  0.290833 -14.448000     0.210389  117.518111
# ...

# %%
df = pd.concat([df_artist, df_genres])
df
# Out:
#       acousticness  danceability    duration_ms    energy  instrumentalness  \
# 0         0.590111      0.467222  250318.555556  0.394003          0.011400
# 1         0.862538      0.441731  287280.000000  0.406808          0.081158
# 2         0.856571      0.348286  328920.000000  0.286571          0.024593
# 3         0.884926      0.425074  262890.962963  0.245770          0.073587
# 4         0.510714      0.467143  270436.142857  0.488286          0.009400
# ...            ...           ...            ...       ...               ...
# 2968      0.222625      0.547082  258099.064530  0.610240          0.143872
# 2969      0.161000      0.863000  206320.000000  0.909000          0.000000
# 2970      0.263261      0.748889  306072.777778  0.622444          0.257227
# 2971      0.993000      0.705667  198417.333333  0.172667          0.468633
# 2972      0.421038      0.629409  171671.690476  0.609369          0.019248
#
# ...

# %%
df.to_csv('preprocessed_data.csv')
