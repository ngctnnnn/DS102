# %%
import pandas as pd

# %%
df = pd.read_csv('./data/weather.csv')

# %%
df.head()
# Out:
#    queryCost  latitude  longitude    resolvedAddress            address  \
# 0          1   32.5625   107.4500     32.5625,107.45     32.5625,107.45
# 1          1   45.4200  -122.6630     45.42,-122.663     45.42,-122.663
# 2          1  -11.1295   -75.3587  -11.1295,-75.3587  -11.1295,-75.3587
# 3          1   28.8378    81.7080     28.8378,81.708     28.8378,81.708
# 4          1   10.3336   123.8978   10.3336,123.8978   10.3336,123.8978
#
#               timezone  tzoffset  feelslikemax  feelslikemin  feelslike  ...  \
# 0        Asia/Shanghai      8.00          90.7          76.0       82.7  ...
# 1  America/Los_Angeles     -8.00          41.4          23.7       35.0  ...
# 2         America/Lima     -5.00           0.0           0.0        NaN  ...
# 3       Asia/Kathmandu      5.75          74.9          74.9       74.9  ...
# 4          Asia/Manila      8.00         105.1          75.2       88.7  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11036 entries, 0 to 11035
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   queryCost        11036 non-null  int64
#  1   latitude         11036 non-null  float64
#  2   longitude        11036 non-null  float64
#  3   resolvedAddress  11036 non-null  object
#  4   address          11036 non-null  object
#  5   timezone         11036 non-null  object
#  6   tzoffset         11036 non-null  float64
#  7   feelslikemax     11004 non-null  float64
#  8   feelslikemin     11004 non-null  float64
#  9   feelslike        10317 non-null  float64
#  10  dew              10282 non-null  float64
#  11  humidity         10282 non-null  float64
#  12  precip           10320 non-null  float64
#  13  precipprob       541 non-null    float64
#  14  precipcover      11007 non-null  float64
#  15  preciptype       0 non-null      float64
# ...
