# %%
import pandas as pd

# %%
df = pd.read_csv('./data/weather.csv')

# %%
df.head()
# Out:
#    queryCost  latitude  longitude resolvedAddress         address  \
# 0          1   32.5625    107.450  32.5625,107.45  32.5625,107.45
# 1          1   32.5625    107.450  32.5625,107.45  32.5625,107.45
# 2          1   45.4200   -122.663  45.42,-122.663  45.42,-122.663
# 3          1   45.4200   -122.663  45.42,-122.663  45.42,-122.663
# 4          1   45.4200   -122.663  45.42,-122.663  45.42,-122.663
#
#               timezone  tzoffset  feelslikemax  feelslikemin  feelslike  ...  \
# 0        Asia/Shanghai       8.0          90.7          76.0       82.7  ...
# 1        Asia/Shanghai       8.0          90.7          76.0       82.7  ...
# 2  America/Los_Angeles      -8.0          41.4          23.7       35.0  ...
# 3  America/Los_Angeles      -8.0          41.4          23.7       35.0  ...
# 4  America/Los_Angeles      -8.0          41.4          23.7       35.0  ...
#
#                 icon     stations  distance  latitude.1  longitude.1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38252 entries, 0 to 38251
# Data columns (total 40 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   queryCost        38252 non-null  int64
#  1   latitude         38252 non-null  float64
#  2   longitude        38252 non-null  float64
#  3   resolvedAddress  38252 non-null  object
#  4   address          38252 non-null  object
#  5   timezone         38252 non-null  object
#  6   tzoffset         38252 non-null  float64
#  7   feelslikemax     38237 non-null  float64
#  8   feelslikemin     38237 non-null  float64
#  9   feelslike        38237 non-null  float64
#  10  dew              38203 non-null  float64
#  11  humidity         38203 non-null  float64
#  12  precip           38252 non-null  float64
#  13  precipprob       0 non-null      float64
#  14  precipcover      38252 non-null  float64
#  15  preciptype       0 non-null      float64
# ...
