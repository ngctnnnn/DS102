# %%
import pandas as pd
import numpy as np

# %%
df_weather = pd.read_csv('data/weather.csv')
df_weather
# Out:
#        queryCost   latitude   longitude           resolvedAddress  \
# 0              1  32.562500  107.450000            32.5625,107.45
# 1              1  45.420000 -122.663000            45.42,-122.663
# 2              1 -11.129500  -75.358700         -11.1295,-75.3587
# 3              1  28.837800   81.708000            28.8378,81.708
# 4              1  10.333600  123.897800          10.3336,123.8978
# ...          ...        ...         ...                       ...
# 11031          1  -7.853409  111.679944  -7.853409423,111.6799444
# 11032          1  33.403080   75.680611   33.40307977,75.68061125
# 11033          1  26.181606   91.772042       26.181606,91.772042
# 11034          1  40.886395   73.472379   40.88639497,73.47237853
# 11035          1  17.465630   78.356505   17.46562972,78.35650524
#
#                         address             timezone  tzoffset  feelslikemax  \
# 0                32.5625,107.45        Asia/Shanghai      8.00          90.7
# ...

# %%
df_weather.columns
# Out:
# Index(['queryCost', 'latitude', 'longitude', 'resolvedAddress', 'address',
#        'timezone', 'tzoffset', 'feelslikemax', 'feelslikemin', 'feelslike',
#        'dew', 'humidity', 'precip', 'precipprob', 'precipcover', 'preciptype',
#        'snow', 'snowdepth', 'windgust', 'windspeed', 'winddir', 'pressure',
#        'cloudcover', 'visibility', 'solarradiation', 'solarenergy', 'uvindex',
#        'moonphase', 'conditions', 'description', 'icon'],
#       dtype='object')

# %%
df_original = pd.read_csv('data/GLC.csv')
df_original = df_original.drop(columns=['Unnamed: 0'])
df_original
# Out:
#        event_id           event_date  \
# 0           684  2008-08-01 00:00:00
# 1           956  2009-01-02 02:00:00
# 2           973  2007-01-19 00:00:00
# 3          1067  2009-07-31 00:00:00
# 4          2603  2010-10-16 12:00:00
# ...         ...                  ...
# 11028     11109  2017-04-01 13:34:00
# 11029     10845  2017-03-25 17:32:00
# 11030     10973  2016-12-15 05:00:00
# 11031     10901  2017-04-29 19:03:00
# 11032     10949  2017-03-13 14:32:00
#
#                                              event_title  \
# 0          Sigou Village, Loufan County, Shanxi Province
# 1                                    Lake Oswego, Oregon
# 2      San Ramon district, 195 miles northeast of the...
# 3                                       Dailekh district
# 4                        sitio Bakilid in barangay Lahug
# ...                                                  ...
# 11028                         Major landslide in Banaran
# ...

# %%
df = pd.merge(df_original, df_weather, on='latitude', how='right')
df
# Out:
#        event_id           event_date  \
# 0           684  2008-08-01 00:00:00
# 1           956  2009-01-02 02:00:00
# 2           973  2007-01-19 00:00:00
# 3          1067  2009-07-31 00:00:00
# 4          2603  2010-10-16 12:00:00
# ...         ...                  ...
# 11969     11109  2017-04-01 13:34:00
# 11970     10845  2017-03-25 17:32:00
# 11971     10973  2016-12-15 05:00:00
# 11972     10901  2017-04-29 19:03:00
# 11973     10949  2017-03-13 14:32:00
#
#                                              event_title  \
# 0          Sigou Village, Loufan County, Shanxi Province
# 1                                    Lake Oswego, Oregon
# 2      San Ramon district, 195 miles northeast of the...
# 3                                       Dailekh district
# 4                        sitio Bakilid in barangay Lahug
# ...                                                  ...
# 11969                         Major landslide in Banaran
# ...
