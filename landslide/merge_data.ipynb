# %%
import pandas as pd
import numpy as np

# %%
df_weather = pd.read_csv('data/weather.csv')
df_weather
# Out:
#        queryCost  latitude   longitude          resolvedAddress  \
# 0              1  32.56250  107.450000           32.5625,107.45
# 1              1  32.56250  107.450000           32.5625,107.45
# 2              1  45.42000 -122.663000           45.42,-122.663
# 3              1  45.42000 -122.663000           45.42,-122.663
# 4              1  45.42000 -122.663000           45.42,-122.663
# ...          ...       ...         ...                      ...
# 38247          1  17.46563   78.356505  17.46562972,78.35650524
# 38248          1  17.46563   78.356505  17.46562972,78.35650524
# 38249          1  17.46563   78.356505  17.46562972,78.35650524
# 38250          1  17.46563   78.356505  17.46562972,78.35650524
# 38251          1  17.46563   78.356505  17.46562972,78.35650524
#
#                        address             timezone  tzoffset  feelslikemax  \
# 0               32.5625,107.45        Asia/Shanghai       8.0          90.7
# ...

# %%
df_weather.columns
# Out:
# Index(['queryCost', 'latitude', 'longitude', 'resolvedAddress', 'address',
#        'timezone', 'tzoffset', 'feelslikemax', 'feelslikemin', 'feelslike',
#        'dew', 'humidity', 'precip', 'precipprob', 'precipcover', 'preciptype',
#        'snow', 'snowdepth', 'windgust', 'windspeed', 'winddir', 'pressure',
#        'cloudcover', 'visibility', 'solarradiation', 'solarenergy', 'uvindex',
#        'moonphase', 'conditions', 'description', 'icon', 'stations',
#        'distance', 'latitude.1', 'longitude.1', 'useCount', 'id', 'name',
#        'quality', 'contribution'],
#       dtype='object')

# %%
df_original = pd.read_csv('data/GLC.csv')
df_original
# Out:
#        Unnamed: 0  event_id           event_date  \
# 0               0       684  2008-08-01 00:00:00
# 1               1       956  2009-01-02 02:00:00
# 2               2       973  2007-01-19 00:00:00
# 3               3      1067  2009-07-31 00:00:00
# 4               4      2603  2010-10-16 12:00:00
# ...           ...       ...                  ...
# 11028       11028     11109  2017-04-01 13:34:00
# 11029       11029     10845  2017-03-25 17:32:00
# 11030       11030     10973  2016-12-15 05:00:00
# 11031       11031     10901  2017-04-29 19:03:00
# 11032       11032     10949  2017-03-13 14:32:00
#
#                                              event_title  \
# 0          Sigou Village, Loufan County, Shanxi Province
# 1                                    Lake Oswego, Oregon
# 2      San Ramon district, 195 miles northeast of the...
# 3                                       Dailekh district
# 4                        sitio Bakilid in barangay Lahug
# ...
