# %%
import pandas as pd

# %%
df = pd.read_csv('data_csv.csv')
df
# Out:
#        0  queryCost  latitude  longitude  \
# 0      1          1  -29.8749    -71.101
# 1      2          1  -29.8749    -71.101
# 2      3          1  -29.8749    -71.101
# 3      4          1  -29.8749    -71.101
# 4      5          1  -29.8749    -71.101
# ..   ...        ...       ...        ...
# 355  356          1  -29.8749    -71.101
# 356  357          1  -29.8749    -71.101
# 357  358          1  -29.8749    -71.101
# 358  359          1  -29.8749    -71.101
# 359  360          1  -29.8749    -71.101
#
#                                       resolvedAddress  address  \
# 0    1700000, La Serena, Coquimbo, República de Chile   700000
# 1    1700000, La Serena, Coquimbo, República de Chile   700000
# 2    1700000, La Serena, Coquimbo, República de Chile   700000
# 3    1700000, La Serena, Coquimbo, República de Chile   700000
# 4    1700000, La Serena, Coquimbo, República de Chile   700000
# ..                                                ...      ...
# ...

# %%
df.head(5)
# Out:
#    0  queryCost  latitude  longitude  \
# 0  1          1  -29.8749    -71.101
# 1  2          1  -29.8749    -71.101
# 2  3          1  -29.8749    -71.101
# 3  4          1  -29.8749    -71.101
# 4  5          1  -29.8749    -71.101
#
#                                     resolvedAddress  address  \
# 0  1700000, La Serena, Coquimbo, República de Chile   700000
# 1  1700000, La Serena, Coquimbo, República de Chile   700000
# 2  1700000, La Serena, Coquimbo, República de Chile   700000
# 3  1700000, La Serena, Coquimbo, República de Chile   700000
# 4  1700000, La Serena, Coquimbo, República de Chile   700000
#
#            timezone  tzoffset  \
# 0  America/Santiago      -3.0
# 1  America/Santiago      -3.0
# 2  America/Santiago      -3.0
# 3  America/Santiago      -3.0
# 4  America/Santiago      -3.0
#
#                                          description        days  ...  \
# 0  Similar temperatures continuing with no rain e...  2021-10-13  ...
# ...
