# %%
import pandas as pd

# %%
df = pd.read_csv('data_csv.csv')
df
# Out:
#        0  queryCost   latitude   longitude       resolvedAddress  \
# 0      1          1  10.762622  106.660172  10.762622,106.660172
# 1      2          1  10.762622  106.660172  10.762622,106.660172
# 2      3          1  10.762622  106.660172  10.762622,106.660172
# 3      4          1  10.762622  106.660172  10.762622,106.660172
# 4      5          1  10.762622  106.660172  10.762622,106.660172
# ..   ...        ...        ...         ...                   ...
# 355  356          1  10.762622  106.660172  10.762622,106.660172
# 356  357          1  10.762622  106.660172  10.762622,106.660172
# 357  358          1  10.762622  106.660172  10.762622,106.660172
# 358  359          1  10.762622  106.660172  10.762622,106.660172
# 359  360          1  10.762622  106.660172  10.762622,106.660172
#
#                   address          timezone  tzoffset  \
# 0    10.762622,106.660172  Asia/Ho_Chi_Minh       7.0
# 1    10.762622,106.660172  Asia/Ho_Chi_Minh       7.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 70 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   0                 360 non-null    int64
#  1   queryCost         360 non-null    int64
#  2   latitude          360 non-null    float64
#  3   longitude         360 non-null    float64
#  4   resolvedAddress   360 non-null    object
#  5   address           360 non-null    object
#  6   timezone          360 non-null    object
#  7   tzoffset          360 non-null    float64
#  8   description       360 non-null    object
#  9   days              360 non-null    object
#  10  datetime          360 non-null    int64
#  11  datetimeEpoch     360 non-null    float64
#  12  tempmax           360 non-null    float64
#  13  tempmin           360 non-null    float64
#  14  temp              360 non-null    float64
#  15  feelslikemax      360 non-null    float64
# ...
